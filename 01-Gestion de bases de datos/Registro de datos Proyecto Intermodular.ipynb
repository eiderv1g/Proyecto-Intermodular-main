# %%
INSERT INTO Alumno (nombre, email, contrasena, telefono) VALUES
('Antonio Rossi', 'antonio@email.com', '1234', '600123123'),
('Laura Pérez', 'laura@email.com', 'abcd', '611111111'),
('Carlos Ficticius','carlos@email.com','1234','600111111'),
('María José Niño','mariajo@email.com','1234','600222222'),
('José María Palomares','josema@email.com','1234','600333333'),
('Adolfo Pinceles','adolfo@email.com','1234','600444444'),
('Ernesto Calpiano','ernesto@email.com','1234','600555555'),
('Lucía Romero','lucia@email.com','1234','600666666'),
('David Torres','david@email.com','1234','600777777');

INSERT INTO Matricula (fecha_matricula, estado, id_alumno) VALUES
('2026-01-10', 'activa', 1),
('2026-02-01', 'activa', 2),
('2026-01-01','activa',1),
('2026-01-02','activa',2),
('2026-01-03','activa',3),
('2026-01-04','suspendida',4),
('2026-01-05','activa',5),
('2026-01-06','finalizada',6),
('2026-01-07','suspendida',7);

INSERT INTO Departamento (nombre, equipoHW) VALUES
('IT', 'Servidores'),
('Soporte', 'PCs'),
('Formación','PCs'),
('Soporte','Servidores');

INSERT INTO Empleado (nombre, email, rol, salario, fecha_contratacion, id_departamento) VALUES
('Carlos Ruiz', 'carlos@empresa.com', 'instructor', 2000, '2024-01-01', 1),
('Ana López', 'ana@empresa.com', 'soporte', 1800, '2024-03-01', 2),
('Sergio Gallardo','sergio@email.com','instructor',2000,'2024-01-01',1),
('Miriam Ocaña','miriam@email.com','instructor',2000,'2024-01-01',1),
('Antonio J. Rossi','antoniorossi@email.com','instructor',2200,'2024-01-01',1),
('Lucía Fernández','lucifer@email.com','admin',2500,'2024-01-01',2);

INSERT INTO Laboratorio (nombre, descripcion, sistema, dificultad, id_empleado) VALUES
('Linux Básico', 'Intro a Linux', 'Linux', 'easy', 1),
('Cyber Básico','Fundamentos de ciberseguridad','Linux','easy',1),
('Reconocimiento','OSINT y escaneo','Linux','medium',2),
('PrivEsc','Escalada de privilegios','Linux','hard',3);

INSERT INTO Desafio (titulo, descripcion, tipo, dificultad, id_laboratorio) VALUES
('Escalada de privilegios', 'Subir permisos', 'privilege escalation', 'medium', 1),
('Intro Linux','Comandos básicos','practica','easy',1),
('Escaneo red','Nmap','practica','medium',2),
('Root exploit','Escalada','practica','hard',3);

INSERT INTO Evento_CTF (nombre, descripcion, fecha_inicio, fecha_fin) VALUES
('CTF Marzo', 'Evento mensual', '2026-03-01', '2026-03-03'),
('CTF Mayo','Evento de hacking','2026-05-08','2026-05-10'),
('CTF Junio','Evento avanzado','2026-06-01','2026-06-03');

INSERT INTO Alumno_Evento VALUES (1,1),(2,1),(3,2),(4,2);

INSERT INTO Alumno_Desafio VALUES (1,1,'2026-03-02', TRUE),(3,2,'2026-05-03',TRUE),(4,3,'2026-05-04',FALSE);

INSERT INTO Incidencia (titulo, descripcion, estado, fecha_creacion, id_alumno, id_empleado) VALUES
('Error login', 'No puedo acceder', 'abierta', '2026-03-05', 1, 2),
('Error login','No puede acceder','abierta','2026-05-01',1,4),
('Fallo lab','No carga','en_proceso','2026-05-02',2,4),
('Bug sistema','Error general','cerrada','2026-05-03',3,4),
('Problema red','Lentitud','abierta','2026-05-04',4,4),
('Cuenta bloqueada','Error acceso','cerrada','2026-05-05',5,4);
